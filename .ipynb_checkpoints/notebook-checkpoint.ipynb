# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import string
from wordcloud import WordCloud
from functools import reduce
from sklearn.preprocessing import LabelEncoder,StandardScaler,FunctionTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline,FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.decomposition import TruncatedSVD
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.linear_model import SGDClassifier,LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score,confusion_matrix,precision_score,recall_score,accuracy_score
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,StackingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from joblib import dump

# %% [markdown]
# ## Outline
# - [Task description](#task_description)
# - [Read tha data](#read_the_data)
# - [Data cleaning](#data_cleaning)
#   - [Handeling missing values](#handeling_missing_values)
#   - [Column Renaming](#column_renaming)
#   - [Encoding](#encoding)
#   - [Handeling duplicates](#handeling_duplicates)
# - [EDA](#eda)
#     - [Basic EDA](#asic_eda)
#     - [Plots](#plots)
#     - [Correlations Analysis](#correlations_analysis)
#     - [Conclusion](#conclusions)
# - [Text preprocessing](#text_preprocessing)
#     - [Capitalization](#capitalization)
#     - [Tokenization](#tokenization)
#     - [Removing special characters](#removing_special_characters)
#     - [Removing stop words](#removing_stop_words)
#     - [Stemming](#stemming)
#     - [Examining & visualizing the results](#examining_results)
# - [Modeling & training](#modeling_and_training)
# - [Evaluation](#evaluation)
#     - [Compare the different models](#comparing_models)
#     - [Building meta models](#building_a_meta_model)
# - [Export the best model](#export_the_best_model)

# %% [markdown]
# ## Task description

# %% [markdown]
# [Dataset](https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset)

# %% [markdown]
# ## Read the data

# %%
data = pd.read_csv("spam.csv", encoding="iso-8859-1")

# %%
data.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 5475  ham  Dhoni have luck to win some big title.so we wi...        NaN
# 2725  ham       No. But we'll do medical missions to nigeria        NaN
# 2066  ham                         Then. You are eldest know.        NaN
# 4462  ham  He said i look pretty wif long hair wat. But i...        NaN
# 5222  ham  5 nights...We nt staying at port step liao...T...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5475        NaN        NaN
# 2725        NaN        NaN
# 2066        NaN        NaN
# 4462        NaN        NaN
# 5222        NaN        NaN

# %% [markdown]
# ## Data cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
data.isna().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %% [markdown]
# ### Handeling missing values

# %% [markdown]
# - most of the values of the last three columns are missing,therefore we're going to drop them.

# %%
data.drop(columns = ["Unnamed: 2","Unnamed: 3","Unnamed: 4"], inplace=True)

# %%
data.columns
# Out:
# Index(['v1', 'v2'], dtype='object')

# %% [markdown]
# ### Columns Renaming

# %%
data.columns = ["label", "message"]
data.columns
# Out:
# Index(['label', 'message'], dtype='object')

# %% [markdown]
# ### Encoding

# %%
encoder = LabelEncoder()

# %%
encoder.fit(data["label"])
# Out:
# LabelEncoder()

# %%
data["label"] = encoder.transform(data["label"])

# %% [markdown]
# ### Handeling duplicated rows

# %%
data.duplicated().sum()
# Out:
# 403

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Basic EDA

# %% [markdown]
# #### Examine the head and the tail of the dataset

# %%
data.head()
# Out:
#    label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...

# %%
data.tail()
# Out:
#       label                                            message
# 5567      1  This is the 2nd time we have tried 2 contact u...
# 5568      0              Will Ì_ b going to esplanade fr home?
# 5569      0  Pity, * was in mood for that. So...any other s...
# 5570      0  The guy did some bitching but I acted like i'd...
# 5571      0                         Rofl. Its true to its name

# %% [markdown]
# #### Examine the dimensions of the dataset

# %%
data.shape
# Out:
# (5169, 2)

# %% [markdown]
# #### Examine the types and the number of null values for each columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   label    5169 non-null   int64
#  1   message  5169 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 121.1+ KB

# %% [markdown]
# #### Examine basic statistics about the numerical attributes

# %%
data.describe()
# Out:
#              label
# count  5169.000000
# mean      0.126330
# std       0.332253
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# ### Plots

# %%
data["label"].value_counts().plot.pie(labels = ["ham", "spam"], autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
data["length"] = data["message"].apply(len)

# %%
plot = sns.histplot(data=data,x="length",hue="label")

# %%
data["Words count"] = data["message"].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
plot = sns.histplot(data=data,x="Words count",hue="label")

# %%
data["Sentence count"] = data["message"].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
plot = sns.histplot(data=data,x="Sentence count",hue="label")

# %% [markdown]
# ### Correlations Analysis

# %%
data.describe()
# Out:
#              label       length  Words count  Sentence count
# count  5169.000000  5169.000000  5169.000000     5169.000000
# mean      0.126330    78.977945    18.455794        1.965564
# std       0.332253    58.236293    13.324758        1.448541
# min       0.000000     2.000000     1.000000        1.000000
# 25%       0.000000    36.000000     9.000000        1.000000
# 50%       0.000000    60.000000    15.000000        1.000000
# 75%       0.000000   117.000000    26.000000        2.000000
# max       1.000000   910.000000   220.000000       38.000000

# %%
correlation_matrix = data.select_dtypes(include=np.number).corr()

# %%
sns.heatmap(data = correlation_matrix, vmin = -1, vmax = 1, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data, hue = "label")
# Out:
# /home/abdelnour/anaconda3/envs/ml/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Conclusion
# - Data is imbalanced.
# - the number of characters and words knowing the label follows a gaussian distribution.
# - the number of words, characters and sentences are highly correlated.

# %% [markdown]
# ## Text preprocessing

# %% [markdown]
# ### Capitalization

# %%
data["message"] = data["message"].str.lower()

# %% [markdown]
# ### Tokenization

# %%
data["tokens"] = data["message"].apply(lambda x : nltk.word_tokenize(x))

# %% [markdown]
# ### Removing special characters

# %%
data["tokens"] = data["tokens"].apply(lambda x : list(filter(str.isalpha,x)))

# %% [markdown]
# ### Removing stop words

# %%
stopwords = set(nltk.corpus.stopwords.words("english"))

# %%
data["tokens"] = data["tokens"].apply(lambda x : [w for w in x if w not in stopwords])

# %% [markdown]
# ### Stemming

# %%
stemmer = nltk.stem.porter.PorterStemmer()

# %%
data["tokens"] = data["tokens"].apply(lambda x : list(map(stemmer.stem, x)))

# %% [markdown]
# ### Examining & visualizing the results

# %%
sample = data.sample(n = 10)
sample[["message","tokens"]]
# Out:
#                                                 message  \
# 1317  win the newest ûïharry potter and the order o...
# 1877  this pen thing is beyond a joke. wont a biro d...
# 201   hello darlin ive finished college now so txt m...
# 1777  buy space invaders 4 a chance 2 win orig arcad...
# 3075  mum, hope you are having a great day. hoping t...
# 4093                           how are you? i miss you!
# 5133  hmm... dunno leh, mayb a bag 4 goigng out dat ...
# 2097       are you the cutest girl in the world or what
# 3834  i'm thinking that chennai forgot to come for a...
# 4684  alright we'll bring it to you, see you in like...
#
#                                                  tokens
# 1317  [win, newest, potter, order, phoenix, book, re...
# 1877  [pen, thing, beyond, joke, wont, biro, master,...
# 201   [hello, darlin, ive, finish, colleg, txt, u, f...
# 1777  [buy, space, invad, chanc, win, orig, arcad, g...
# 3075  [mum, hope, great, day, hope, text, meet, well...
# 4093                                             [miss]
# 5133  [hmm, dunno, leh, mayb, bag, goigng, dat, smal...
# 2097                              [cutest, girl, world]
# 3834            [think, chennai, forgot, come, auction]
# 4684           [alright, bring, see, like, lt, gt, min]

# %%
data["transformed_text"] = data["tokens"].apply(' '.join)

# %%
wc = WordCloud()

# %%
ham_text = " ".join(data["transformed_text"][data["label"] == 0].tolist())

# %%
spam_text = " ".join(data["transformed_text"][data["label"] == 1].tolist())

# %%
ham_cloud = wc.generate(ham_text)
plt.imshow(ham_cloud)

# %%
spam_cloud = wc.generate(spam_text)
plt.imshow(spam_cloud)

# %%
ham_tokens = reduce(lambda a,b: a+b,data["tokens"][data["label"] == 0].tolist())

# %%
spam_tokens = reduce(lambda a,b: a+b,data["tokens"][data["label"] == 1].tolist())

# %%
ham_dist = pd.Series(nltk.probability.FreqDist(ham_tokens))

# %%
spam_dist = pd.Series(nltk.probability.FreqDist(spam_tokens))

# %%
def plot_topk_results(dist, k = 20):
    sort = np.argsort(dist)
    dist = dist[sort][-k:]
    sns.barplot(y=dist,x=dist.index)
    plt.xticks(rotation=80)

# %%
plot_topk_results(ham_dist, k = 30)

# %%
plot_topk_results(spam_dist, k = 30)

# %% [markdown]
# ## Modeling & Training

# %%
X_train, X_test, y_train, y_test = train_test_split(data["transformed_text"], data["label"], test_size=0.25)

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
gnb = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("pca",TruncatedSVD(n_components=100)),
    ("estimator",GaussianNB())
])

# %%
gnb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('pca', TruncatedSVD(n_components=100)),
#                 ('estimator', GaussianNB())])

# %% [markdown]
# #### Multinomial Naive Bayes

# %%
mnb = Pipeline(steps=[
    ("vectoriser",CountVectorizer(binary=True)),
    ("estimator",MultinomialNB())
])

# %%
mnb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer(binary=True)),
#                 ('estimator', MultinomialNB())])

# %% [markdown]
# #### Descion Tree

# %%
tree_classifier = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("estimator",DecisionTreeClassifier())
])

# %%
tree_classifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('estimator', DecisionTreeClassifier())])

# %% [markdown]
# #### SGDClassifier

# %%
sgd_classifier = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("pca",TruncatedSVD(n_components=100)),
    ("scaler", StandardScaler()),
    ("estimator",SGDClassifier(loss='log_loss'))
])

# %%
sgd_classifier.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('pca', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator', SGDClassifier(loss='log_loss'))])

# %% [markdown]
# #### Logestic Regressor

# %%
logistic_regressor = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("pca",TruncatedSVD(n_components=100)),
    ("scaler", StandardScaler()),
    ("estimator",LogisticRegression())
])

# %%
logistic_regressor.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('pca', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator', LogisticRegression())])

# %% [markdown]
# ### K-Nearest-Neighbors

# %%
k_neighbors_classifier = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("pca",TruncatedSVD(n_components=100)),
    ("scaler", StandardScaler()),
    ("estimator",KNeighborsClassifier())
])

# %%
k_neighbors_classifier.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('pca', TruncatedSVD(n_components=100)),
#                 ('scaler', StandardScaler()),
#                 ('estimator', KNeighborsClassifier())])

# %% [markdown]
# ### Support Vector Machine

# %%
svc = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("estimator",SVC(kernel="sigmoid", gamma=1.0))
])

# %%
svc.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('estimator', SVC(gamma=1.0, kernel='sigmoid'))])

# %% [markdown]
# ### Random Forest

# %%
random_forest_classifier = Pipeline(steps=[
    ("vectoriser",CountVectorizer()),
    ("estimator",RandomForestClassifier())
])

# %%
random_forest_classifier.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectoriser', CountVectorizer()),
#                 ('estimator', RandomForestClassifier())])

# %% [markdown]
# ## Evaluation

# %%
metrics = [accuracy_score,f1_score,confusion_matrix,precision_score,recall_score]
models  = [gnb,mnb,tree_classifier,sgd_classifier,logistic_regressor,k_neighbors_classifier,svc,random_forest_classifier]

# %%
def evaluate(models, metrics, X, y):

    algorithms = [model["estimator"].__class__.__name__ for model in models]
    columns = ["Algorithm"] + [metric.__name__ for metric in metrics]
    results = np.zeros(shape=(len(models),len(columns))).tolist()
    
    for i,model in enumerate(models):
        y_hat = model.predict(X)
        results[i][0] = algorithms[i]
        
        for j,metric in enumerate(metrics):
            
            value = metric(y, y_hat)
            results[i][j+1] = value

    return pd.DataFrame(data=results,columns=columns)

# %%
evaluation_df = evaluate(models, metrics, X_test, y_test)
evaluation_df
# Out:
#                 Algorithm  accuracy_score  f1_score         confusion_matrix  \
# 0              GaussianNB        0.894045  0.630728  [[1039, 78], [59, 117]]
# 1           MultinomialNB        0.972158  0.892857  [[1107, 10], [26, 150]]
# 2  DecisionTreeClassifier        0.965197  0.863222  [[1106, 11], [34, 142]]
# 3           SGDClassifier        0.961330  0.848485  [[1103, 14], [36, 140]]
# 4      LogisticRegression        0.965971  0.865031   [[1108, 9], [35, 141]]
# 5    KNeighborsClassifier        0.926527  0.636015    [[1115, 2], [93, 83]]
# 6                     SVC        0.920340  0.694362  [[1073, 44], [59, 117]]
# 7  RandomForestClassifier        0.959010  0.823920   [[1116, 1], [52, 124]]
#
#    precision_score  recall_score
# 0         0.600000      0.664773
# 1         0.937500      0.852273
# 2         0.928105      0.806818
# 3         0.909091      0.795455
# 4         0.940000      0.801136
# 5         0.976471      0.471591
# 6         0.726708      0.664773
# 7         0.992000      0.704545

# %%
melted_df = pd.melt(evaluation_df, id_vars=['Algorithm'], var_name='Metric', value_name='Value')
melted_df.drop(index=melted_df.index[melted_df["Metric"] == "confusion_matrix"], inplace=True)

# %%
sns.barplot(x='Algorithm', y='Value', hue='Metric', data=melted_df)
_ = plt.xticks(rotation=80)

# %% [markdown]
# - From the results above the best model is MultinominalNB.

# %% [markdown]
# ### Building a Meta Classifier

# %% [markdown]
# #### Boosting

# %%
voting_classifier = VotingClassifier(estimators=[
    ("mnb", mnb),
    ("sgd_classifier", sgd_classifier),
    ("logistic_regressor", logistic_regressor),
    ("random_forest_classifier",random_forest_classifier)
], voting = "soft")

# %%
voting_classifier = Pipeline(steps=[
    ("estimator", voting_classifier)
])

# %%
voting_classifier.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('estimator',
#                  VotingClassifier(estimators=[('mnb',
#                                                Pipeline(steps=[('vectoriser',
#                                                                 CountVectorizer()),
#                                                                ('estimator',
#                                                                 MultinomialNB())])),
#                                               ('sgd_classifier',
#                                                Pipeline(steps=[('vectoriser',
#                                                                 CountVectorizer()),
#                                                                ('pca',
#                                                                 TruncatedSVD(n_components=100)),
#                                                                ('scaler',
#                                                                 StandardScaler()),
#                                                                ('estimator',
#                                                                 SGDClassifier(loss='log_loss'))])),
#                                               ('logistic_regressor',
#                                                Pipeline(steps=[('vectoriser',
#                                                                 CountVectorizer()),
#                                                                ('pca',
#                                                                 TruncatedSVD(n_components=100)),
#                                                                ('scaler',
#                                                                 StandardScaler()),
#                                                                ('estimator',
#                                                                 LogisticRegression())])),
#                                               ('random_forest_classifier',
#                                                Pipeline(steps=[('vectoriser',
#                                                                 CountVectorizer()),
#                                                                ('estimator',
#                                                                 RandomForestClassifier())]))],
#                                   voting='soft'))])

# %% [markdown]
# ### Stacking

# %%
staking_classifier = StackingClassifier(estimators=[
    ("mnb",mnb),
    ("sgd_classifier", sgd_classifier),
    ("logistic_regressor", logistic_regressor),
    ("random_forest_classifier",random_forest_classifier)
], final_estimator = SGDClassifier())

# %%
staking_classifier = Pipeline(steps=[
    ("estimator", staking_classifier)
])

# %%
staking_classifier.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('estimator',
#                  StackingClassifier(estimators=[('mnb',
#                                                  Pipeline(steps=[('vectoriser',
#                                                                   CountVectorizer()),
#                                                                  ('estimator',
#                                                                   MultinomialNB())])),
#                                                 ('sgd_classifier',
#                                                  Pipeline(steps=[('vectoriser',
#                                                                   CountVectorizer()),
#                                                                  ('pca',
#                                                                   TruncatedSVD(n_components=100)),
#                                                                  ('scaler',
#                                                                   StandardScaler()),
#                                                                  ('estimator',
#                                                                   SGDClassifier(loss='log_loss'))])),
#                                                 ('logistic_regressor',
#                                                  Pipeline(steps=[('vectoriser',
#                                                                   CountVectorizer()),
#                                                                  ('pca',
#                                                                   TruncatedSVD(n_components=100)),
#                                                                  ('scaler',
#                                                                   StandardScaler()),
#                                                                  ('estimator',
#                                                                   LogisticRegression())])),
#                                                 ('random_forest_classifier',
#                                                  Pipeline(steps=[('vectoriser',
#                                                                   CountVectorizer()),
#                                                                  ('estimator',
#                                                                   RandomForestClassifier())]))],
#                                     final_estimator=SGDClassifier()))])

# %%
evaluation_df = evaluate([voting_classifier,staking_classifier], metrics, X_test, y_test)
evaluation_df
# Out:
#             Algorithm  accuracy_score  f1_score        confusion_matrix  \
# 0    VotingClassifier        0.972158  0.888199  [[1114, 3], [33, 143]]
# 1  StackingClassifier        0.976798  0.908537  [[1114, 3], [27, 149]]
#
#    precision_score  recall_score
# 0         0.979452      0.812500
# 1         0.980263      0.846591

# %% [markdown]
# - the meta models are just a little bit better than the RandomForestClassifier.

# %% [markdown]
# ## Export the best model

# %% [markdown]
# #### Build a pipeline containing all the preprocessing

# %%
def transform_text(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    tokens = [w for w in tokens if str.isalpha(w)]
    tokens = [w for w in tokens if w not in stopwords]
    tokens = [stemmer.stem(w) for w in tokens]
    return ' '.join(tokens)

# %%
def transform_ds(X):
    return np.array(list(map(transform_text, X)))

# %%
model = Pipeline(steps=[
    ("transforme_text",FunctionTransformer(func=transform_ds)),
    ("estimator",staking_classifier),
])

# %% [markdown]
# #### try on a raw sample

# %%
x = np.array([
    "Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's"
])

# %%
model.predict(x)
# Out:
# array([1])

# %%
model.score(X_test,y_test)
# Out:
# 0.9775715390564579

# %% [markdown]
# #### save the model

# %%
dump(value = model, filename="staking_classifier.joblib")
# Out:
# ['staking_classifier.joblib']
